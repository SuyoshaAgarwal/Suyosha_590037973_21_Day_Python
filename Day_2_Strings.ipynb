# %%
message = "  Learn Python  "
print(message.strip())
# Out:
# Learn Python

# %%
word = "notebook"
print(word[0], word[-1])
# Out:
# n k

# %%
text = "programming"
print(text[0:6])
print(text[6:])
# Out:
# progra
# mming

# %%
csv_line = "red,green,blue"
print(csv_line.split(","))
# Out:
# ['red', 'green', 'blue']

# %%
parts = ["Python", "is", "fun"]
print(" ".join(parts))
# Out:
# Python is fun

# %%
sentence = "Python makes data work"
print(sentence.replace("data", "ideas"))
# Out:
# Python makes ideas work

# %%
email = "student@example.com"
print("@" in email)
print(email.endswith(".com"))
# Out:
# True
# True

# %%
name = "ravi"
print(name.capitalize())
print(name.center(12, "-"))
# Out:
# Ravi
# ----ravi----

# %%
product = "Laptop Pro"
price = 55000
slug = product.lower().replace(" ", "-")
print(f'{slug}: Rs. {price:,}')
# Out:
# laptop-pro: Rs. 55,000

# %%
text = "Python"
print(len(text))
print(text[::-1])
# Out:
# 6
# nohtyP
