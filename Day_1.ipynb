# %%
name = "Suyosha"
print(name)
# Out:
# Suyosha

# %%
age = 25
city = "Dehradun"
print("The city is", city, "and the age is", age)
# Out:
# The city is Dehradun and the age is 25

# %%
a = 10
b = 10.5
c = "10"
d = True

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
price = 499.99
print("The type of price is", type(price))
# Out:
# The type of price is <class 'float'>

# %%
x = 10
print(x)
x = 20
print(x)
# Out:
# 10
# 20

# %%
name = "Python"
version = 3
print(name, version)
# Out:
# Python 3

# %%
student name = "Rahul"
print(student name)

#The error is in the variable name. It is invalid as it has a space.
# Out:
#   Cell In[11], line 1
#     student name = "Rahul"
#             ^
# SyntaxError: invalid syntax

# %%
student_name = 1 #Valid
2student = 1 #Invalid
student2 = 1 #Valid
student-name = 1 #Invalid 
_score = 1 #Valid
# Out:
#   Cell In[12], line 2
#     2student = 1 #Invalid
#     ^
# SyntaxError: invalid decimal literal

# %%
a = 5
b = 3 
print(a+b) #8
print(a*b) #15
# Out:
# 8
# 15

# %%
length = 10
width = 5
area = length * width
print("The area of the rectangle = ", area)
# Out:
# The area of the rectangle =  50

# %%
x = "10"
y = "20"
print(x + y) #1020
# Out:
# 1020

# %%
number = "25"
number = int(number) + 5
print(number)
# Out:
# 30

# %%
x = 10
y = float(x)
print(y) 
print(type(y)) #Float
# Out:
# 10.0
# <class 'float'>

# %%
price = 99.5 
price = int(price)
print(price)
# Out:
# 99

# %%
a = 10
b = 3

print (a/b) #3.33
print(a//b) #3
print(a%b) #1
# Out:
# 3.3333333333333335
# 3
# 1

# %%
a, b, c, = 10, 20, 30
print(a, b, c)
# Out:
# 10 20 30

# %%
x = 5
x = x + 10 #15
x = x*2 #30
print(x)
# Out:
# 30

# %%
item = "Laptop"
price = 50000
quantity = 2 
total_cost = price * quantity
print("The total cost is", total_cost)
# Out:
# The total cost is 100000

# %%
#Incorrect Code 
# age = "20" 
#next_age = age + 1 
#print(next_age)

#Corrected Code 

age = 20 #Removed the double quotes so that it reads as an integer
next_age = age + 1
print(next_age)
# Out:
# 21

# %%
Student_Name = "Rahul"
Age = 20
Course = "Python Programming"
Marks_In_Subject_1 = 80
Marks_In_Subject_2 = 90
Marks_In_Subject_3 = 70

Total_Marks = Marks_In_Subject_1 + Marks_In_Subject_2 + Marks_In_Subject_3
Average_Marks = Total_Marks / 3

print("Student:", Student_Name)
print("Age:", Age)
print("Course:", Course)
print("Total Marks:", Total_Marks)
print("Average Marks:", Average_Marks)
# Out:
# Student: Rahul
# Age: 20
# Course: Python Programming
# Total Marks: 240
# Average Marks: 80.0
